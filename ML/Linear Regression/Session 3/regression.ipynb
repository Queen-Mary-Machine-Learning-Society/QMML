# %%
import os
import sys
import pandas as pd
from sklearn.model_selection import train_test_split

sys.path.insert(0, os.path.abspath('..'))
from src.regression_class import LinearRegression

base_path = os.path.join('..', 'src')
df_easy   = pd.read_csv(os.path.join(base_path, "easy_dataset.csv"))
df_medium = pd.read_csv(os.path.join(base_path, "medium_dataset.csv"))
df_hard   = pd.read_csv(os.path.join(base_path, "hard_dataset.csv"))

def split_dataset(df, test_size=0.15, random_state=42):
    X = df.drop(columns=["y"])
    y = df["y"]
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=test_size, random_state=random_state
    )
    return X_train, X_test, y_train, y_test

X_train_easy,   X_test_easy,   y_train_easy,   y_test_easy   = split_dataset(df_easy)
X_train_medium, X_test_medium, y_train_medium, y_test_medium = split_dataset(df_medium)
X_train_hard,   X_test_hard,   y_train_hard,   y_test_hard   = split_dataset(df_hard)

# %% [markdown]
# ## Exercises 3
#
# Start Session 3 exercises here. You can save your implementation in the `src/regression_class.py` file located in the parent folder.
#
# I recommend **not** using Generative AI to solve the core tasks. Use it only for help with notation (e.g., "How do I represent a matrix in Python?" or "What is the code to multiply two matrices?").

# %%
# Exercise 1

def center_vector():
    pass

def center_matrix():
    pass

# %%
# Exercise 2

def gram_schmidt():
    pass

# %%
# Exercise 3

def compute_gamma():
    pass

# %%
# Exercise 4

def compute_beta():
    pass

# %%
# Exercise 5

def compute_ortho_ols():
    pass
