# %%
import pandas as pd
import numpy as np
import torch

# %%
dataset_1 = pd.read_csv('hackathon_data/stock_1_train.csv')

# %%
dataset_1
# Out:
#           col_0     col_1     col_2     col_3     col_4      target
# 0      1.574674  0.170111 -0.045997  0.758763  0.185289  223.453581
# 1     -0.802095 -0.246373  1.640907 -0.141742 -0.163337  211.253687
# 2      0.216712  0.468679 -0.786830 -0.152416  0.293351  280.980886
# 3      0.864578 -0.343601 -1.563815  0.621198  1.124796  266.650511
# 4      1.465125 -0.861386 -0.950072 -0.218991 -0.597203  216.206945
# ...         ...       ...       ...       ...       ...         ...
# 19994  1.303237  0.474954  0.263489 -0.700718 -0.341041  221.232684
# 19995 -0.187980 -0.328975 -0.016282  0.577255 -0.647026  248.174244
# 19996 -0.349532  1.305488  0.273586  0.797979  0.720430  278.366141
# 19997 -0.443370  1.096142 -0.722360 -0.594727  0.010247  297.370878
# 19998  2.526569  0.297506 -1.783894 -0.360988 -1.255813  250.789915
#
# [19999 rows x 6 columns]
